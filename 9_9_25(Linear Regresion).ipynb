# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
# 2. Importing dataset
data = pd.read_csv('./Dataset/Salary_Data.csv')
dataset = data
dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
X = dataset.iloc[:,:-1].values
Y = dataset.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=1/3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
# prisecting the test swt results
import matplotlib.pyplot as plt
plt.scatter(X_train,Y_train,color="red")
plt.scatter(X_test,Y_test,color="blue")
plt.plot(X_test,regressor.predict(X_test),color='yellow')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
test = regressor.predict([[5]])
test
# Out:
# array([73545.90445964])

# %% [markdown]
# Income Dataset

# %%
data = pd.read_csv('./Dataset/income_data.csv')
X = data.iloc[:,1:-1]
Y = data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=1/3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor  = LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_train,Y_train,color="red")
plt.scatter(X_test,Y_test,color="blue")
plt.plot(X_train,regressor.predict(X_train),color="yellow")

# %%
#Create the dataset
data ={
    'Hours_Studied': [2,4,6,8,10],
    'Classess_Attended': [3,4,5,6,8],
    'Final_Score': [665,70,75,85,95]
}

# Use Ordinary least squares (OLS) model
#Predict final score for a new student who studied 7 hours and attended 5 classes

# %%
import statsmodels.api as sm
# Convert dictionary to DataFrame
df = pd.DataFrame(data)

# Define independent (X) and dependent (y) variables
X = df[['Hours_Studied', 'Classess_Attended']]
y = df['Final_Score']

# Add constant (for intercept)
X = sm.add_constant(X)

# Fit Ordinary Least Squares (OLS) model
model = sm.OLS(y, X).fit()

# Display summary of the model
print(model.summary())

# Predict Final Score for a new student (7 hours studied, 5 classes attended)
new_student = pd.DataFrame({'const': [1], 'Hours_Studied': [7], 'Classess_Attended': [5]})
predicted_score = model.predict(new_student)

print("\nPredicted Final Score for a student who studied 7 hours and attended 5 classes:", predicted_score[0])
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            Final_Score   R-squared:                       0.600
# Model:                            OLS   Adj. R-squared:                  0.200
# Method:                 Least Squares   F-statistic:                     1.500
# Date:                Tue, 09 Sep 2025   Prob (F-statistic):              0.400
# Time:                        21:17:52   Log-Likelihood:                -32.074
# No. Observations:                   5   AIC:                             70.15
# Df Residuals:                       2   BIC:                             68.98
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                47.5000    639.944      0.074      0.948   -2705.956    2800.956
# ...
